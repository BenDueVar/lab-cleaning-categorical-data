# %% [markdown]
# 1. Use the numerical variables from our dataset this week.
# 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
# 3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv('numerical.csv')

# %%
for column in df.columns:
    sns.histplot(df[column], bins=20)
    plt.show()

# %%
# customer_lifetime_value = exponential distribution
# income = undefined
# monthly_premium_auto = exponential distribution
# months_since_last_claim = exponential distribution
# months_since_policy_inception = undefined
# number_of_open_complaints = exponential distribution
# number_of_policies = exponential distribution
# total_claim_amount = normal distribution

# %%
# mask = (df == 0)
# df_zero = df[df.columns[mask.any()]]
# df_zero

# %%
# df_log = df[['number_of_policies', 'monthly_premium_auto','customer_lifetime_value']]
# df_log

# %%
df_log = df.apply(lambda x: np.log10(x) if np.issubdtype(x.dtype, np.number) else x)
df_log
# Out:
# C:\Users\benja\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    3.441462  4.750308              1.838849
# 1                    4.110166  4.688126              2.033424
# 2                    3.883426      -inf              2.025306
# 3                    3.449277  4.641831              1.863323
# 4                    3.916785  4.798664              1.838849
# ...                       ...       ...                   ...
# 8670                 4.369327  4.856976              1.863323
# 8671                 3.490873  4.334534              1.897627
# 8672                 3.911897      -inf              1.929419
# 8673                 3.876474  4.341256              1.982271
# 8674                 3.416946      -inf              1.886491
#
# ...

# %%
for column in df_log.columns:
    sns.histplot(df_log[column], bins=20)
    plt.show()

# %%
# customer lifetime value reduce the negative skew
# income changed completely, from an undefined shape where only one bin was extremely high and the rest remain flat, 
# now is a positive skew plot
# montlhy premium auto remains negatively skewed
# months since last claim is positively skewed and before it was negatively skewed
# months since policy inception from undefined almost flat at high value shape to a positive skew shape
# number of open complaints is negatively skewed with big gaps 
# number of policies is negatively skewed with big gaps
# total claim amount now is positively skewed and before it was somehow more centered
